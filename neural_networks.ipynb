# %% [markdown]
# ## Foundational Components of Neural Networks

# %% [markdown]
# ### Perceptron

# %%
import torch
import torch.nn as nn

# %%
class Perceptron(nn.Module):
    def __init_(self, input_dim):
        super(Perceptron, self).__init_()
        self.fc1 = nn.Linear(input_dim, 1)
        
    def forward(self,x_in):
        return torch.sigmoid(self.fc1(x_in)).squeeze()

# %% [markdown]
# ### Activation Functions

# %%
# Sigmoid

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
x = torch.range(-5., 5., 0.1)
y = torch.sigmoid(x)
plt.plot(x.numpy(), y.numpy())
plt.show();
# Out:
# /Users/kumarujjawal/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: torch.range is deprecated in favor of torch.arange and will be removed in 0.5. Note that arange generates values in [start; end), not [start; end].
#   """

# %%
# Tanh
# %matplotlib inline
plt.figure(figsize=(10,6))

x = torch.arange(-5., 5., 0.1)
y = torch.tanh(x)
plt.plot(x.numpy(), y.numpy())

# %%
# ReLu
plt.figure(figsize=(10,6))

relu = torch.nn.ReLU()
x = torch.arange(-5., 5., 0.1)
y = relu(x)
plt.plot(x.numpy(), y.numpy())

# %%
# PReLu

plt.figure(figsize=(10,6))

prelu = torch.nn.PReLU(num_parameters=1)
x = torch.arange(-5., 5., 0.1)
y = prelu(x)
plt.plot(x.detach().numpy(), y.detach().numpy())

# %%
# Softmax

softmax = nn.Softmax(dim=1)
x = torch.randn(1,3)
y = softmax(x)
print(x)
print(y)
print(torch.sum(y, dim=1))
# Out:
# tensor([[ 1.5427, -2.0733,  1.0484]])
# tensor([[0.6109, 0.0164, 0.3726]])
# tensor([1.])

# %% [markdown]
# ### Loss Functions

# %%
# Mean Squared Error Loss

mse_loss = nn.MSELoss()
outputs = torch.randn(3, 5, requires_grad=True) 
targets = torch.randn(3, 5)
loss = mse_loss(outputs, targets)
print(loss)
# Out:
# tensor(2.5851, grad_fn=<MseLossBackward>)

# %%
# Categorical Cross Entropy Loss
